# %%
import pandas as pd

df = pd.read_csv("tabela.csv", sep=';')

# %%
linha = df.iloc[311]
print(linha)
# Out:
# Rodada                     32
# TimeCasa             Cruzeiro
# TimeFora             Flamengo
# CA_Casa                     0
# CV_Casa                     0
# Chutes_Casa                 5
# Escanteios_Casa             9
# Faltas_Casa                 9
# Impedimentos_Casa           2
# CA_Fora                     0
# CV_Fora                     1
# Chutes_Fora                 6
# Escanteios_Fora             3
# Faltas_Fora                19
# Impedimentos_Fora           0
# Name: 311, dtype: object
